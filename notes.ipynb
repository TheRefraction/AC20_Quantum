# %%
# %matplotlib inline

# %%
# %run "script.py"
# Out:
# Number of qubits: 8
# >>> Circuit ops (ISA): OrderedDict({'rz': 34, 'sx': 17, 'measure': 8, 'barrier': 2})
# >>> Job ID: d10cd5b1-7e92-45a5-ac9d-1532f19053b8
# >>> Job Status: JobStatus.RUNNING
# >>> PrimitiveResult([SamplerPubResult(data=DataBin(c=BitArray(<shape=(), num_shots=1024, num_bits=9>)), metadata={'shots': 1024, 'circuit_metadata': {}})], metadata={'version': 2})
# Balanced (classic): False. Took 0 seconds.
