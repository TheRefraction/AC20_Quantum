# %%
# %matplotlib inline

# %%
# %run "script.py"
# Out:
# [INFO] : Running on IBM Quantum service
# [INFO] : Running experiments with 1000 shots
# [INFO] : Circuit transpilation will be run with a 2-level optimization
# Now running with 4 qubits (1st register)
# Initializing quantum circuit
# Backend : ibm_sherbrooke
# Transpiling quantum circuit
# Running job : <bound method BasePrimitiveJob.job_id of <RuntimeJobV2('cxzwgjtcw2k0008jbs9g', 'sampler')>>
# Time estimation : {'quantum_seconds': 2.182973888701153}
# Result : {'1101': 852, '0101': 33, '1100': 32, '1001': 55, '1111': 11, '0001': 3, '0000': 7, '1000': 4, '1010': 1, '0100': 1, '1011': 1}
# Real Constant Value : 0
# Constant (classic) : False. Took 0.0 seconds.
# ----------------------------------------------------------
# Now running with 6 qubits (1st register)
# Initializing quantum circuit
# Backend : ibm_sherbrooke
# Transpiling quantum circuit
# Running job : <bound method BasePrimitiveJob.job_id of <RuntimeJobV2('cxzwhky6vek0008r7fc0', 'sampler')>>
# ...
