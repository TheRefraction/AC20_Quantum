# %%
# %matplotlib inline

# %%
# %run "script.py"
# Out:
# Number of qubits: 100
# ibm_kyiv
# <bound method BasePrimitiveJob.job_id of <RuntimeJobV2('cxy4y1gy1ae0008nee2g', 'sampler')>>
# {'quantum_seconds': 2.1714575038575714}
# PrimitiveResult([SamplerPubResult(data=DataBin(meas=BitArray(<shape=(), num_shots=1000, num_bits=101>)), metadata={'circuit_metadata': {}})], metadata={'execution': {'execution_spans': ExecutionSpans([SliceSpan(<start='2025-01-06 21:45:45', stop='2025-01-06 21:47:19', size=1000>)])}, 'version': 2})
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File ~\PycharmProjects\Quantum\script.py:123
#     119     print(result)
#     121     plot_histogram(result[0].data.meas.get_counts())
# --> 123 balanced, time_elapsed = is_balanced(n, c, d)
#     124 print(f"Balanced (classic): {balanced}. Took {time_elapsed} seconds.")
#     125 print(f"Real Constant Value (balanced otherwise): {c}")
#
# ...

# %%
# %run "script.py"
# Out:
# Number of qubits: 44
